# %% [markdown]
# <a href="https://colab.research.google.com/github/YasuharuSuzuki/26_programing2/blob/main/" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🤹🏼 Section 6 関数の高度な利用、クラス定義
# ## 🌍 Section 6-2 map(),filter() に自作の関数を指定する

# %% [markdown]
# ---

# %% [markdown]
# ### 🌐 関数 参考サイト
# #### [参考サイト1【Python早見表】関数オブジェクト](https://chokkan.github.io/python/04function.html#id8)

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## 🗺 サンプルプログラム4　map()で自作の関数を指定する
# - map()に独自の関数を指定して、リストの各値に対して指定の関数を実行しましょう

# %%
# def キーワードを用いた関数を使用した時の例
def double(x):
    return x * 2

nums1 = [4, 3, 7, 6, 2, 1]
nums2 = list(map(double,nums1))
print(nums2)
# Out:
# [8, 6, 14, 12, 4, 2]

# %%
# 無名関数を使用した時の例
nums1 = [4, 3, 7, 6, 2, 1]
nums3 = list(map(lambda x : x * 2,nums1))
print(nums3)
# Out:
# [8, 6, 14, 12, 4, 2]

# %% [markdown]
# ---

# %% [markdown]
# ## 🌏 練習プログラム4　map()で自作の関数を指定する (10点)
# 1️⃣ map()関数に渡す関数を自作してみましょう。題材は何でも良いです。
# 2️⃣ map()関数に渡す関数を無名関数で自作してみましょう。

# %%
# 1. map()関数に渡す関数を自作してみましょう。
# 定義する関数は何でも良いですが、このNotebookのサンプルプログラムや教科書の値とは違う独自の関数を定義しましょう
# 変数名も独自のものに変えましょう

# ここにPythonプログラムを記述してください
# Out:
# ['セキセイインコ', 'コザクラインコ', 'コザクラインコ', '文鳥', '文鳥', 'オカメインコ']

# %%
# 2. map()関数に渡す関数を無名関数で自作してみましょう。
# 定義する無名関数は何でも良いですが、このNotebookのサンプルプログラムや教科書の値とは違う独自の関数を定義しましょう
# 変数名も独自のものに変えましょう

# ここにPythonプログラムを記述してください
# Out:
# ['セキセイインコ', 'コザクラインコ', 'コザクラインコ', '文鳥', '文鳥', 'オカメインコ']

# %%
#@title 送信処理用共通プログラム（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown 解答の送信に必要です。（中身は絶対に修正しないでください）

import os
os.makedirs(".client/python", exist_ok=True)  # 隠しフォルダを作成
# !wget -q https://raw.githubusercontent.com/YasuharuSuzuki/26_programing2/main/91_notebook_client/src/setup.sh -O .client/setup.sh   # 外部コードをダウンロードして隠しフォルダに配置
# !chmod +x ./.client/setup.sh
# !bash ./.client/setup.sh # 実行

# モジュールの初期化
exec(open('.client/client_setup.py').read())

# ノートブック固有の設定
NOTEBOOK_PATH = "06_関数の高度な利用、クラス定義/02_自作の関数を指定する.ipynb"
set_notebook_config(NOTEBOOK_PATH)

# %%
#@title 問4 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=4, button_name="練習プログラム"))

# %% [markdown]
# ---
# ---
# ---
# ---
# ---

# %% [markdown]
# ## 🎚️ サンプルプログラム5　filter()で自作の関数を指定する
# - filter()に独自の関数を指定して、条件に合う要素だけを抜き出してみましょう

# %%
nums1 = [4, -3, 7, -6, -2, 1]
nums4 = list(filter(lambda x : x > 0,nums1))
print(nums4)
# Out:
# [4, 7, 1]

# %% [markdown]
# ---

# %% [markdown]
# ## 🌪️ 練習プログラム5　filter()で自作の関数を指定する (10点)
# 1️⃣ filter()関数に渡す関数を自作してみましょう。題材は何でも良いです。
#
# <!-- PROBLEM_TYPE: SYNTAX_EXERCISE -->

# %%
# 1. filter()関数に渡す関数を自作してみましょう。
# 定義する関数は何でも良いですが、このNotebookのサンプルプログラムや教科書の値とは違う独自の関数を定義しましょう
# 変数名も独自のものに変えましょう

# ここにPythonプログラムを記述してください
# Out:
# ['セキセイインコ', 'コザクラインコ', 'コザクラインコ', 'オカメインコ']

# %%
#@title 問5 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=5, button_name="練習プログラム"))
