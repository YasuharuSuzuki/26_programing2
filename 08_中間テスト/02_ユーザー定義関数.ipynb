# %% [markdown]
# <a href="https://colab.research.google.com/github/YasuharuSuzuki/26_programing2/blob/main/" target="_parent">
# <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 👨🏻‍💻 02_ユーザー定義関数に関する問題

# %% [markdown]
# ## 用語の理解を問う問題
# - 以下の問題について、正解となる選択肢を出力してください
# ※4択問題は1回目の回答のみが有効です。何度も提出することは出来ませんので、ご注意ください。

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題7 関数内の変数 (3点)
# - 関数内で定義された変数で、関数の外部からアクセスできない変数を何と呼ぶか？
#
#     📕 1. グローバル変数
#     📗 2. ローカル変数
#     📘 3. プライベート変数
#     📙 4. パブリック変数

# %%
# 正解を出力してください
print('')

# %%
#@title 送信処理用共通プログラム（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown 解答の送信に必要です。（中身は絶対に修正しないでください）

import os
os.makedirs(".client/python", exist_ok=True)  # 隠しフォルダを作成
# !wget -q https://raw.githubusercontent.com/YasuharuSuzuki/26_programing2/main/91_notebook_client/src/setup.sh -O .client/setup.sh   # 外部コードをダウンロードして隠しフォルダに配置
# !chmod +x ./.client/setup.sh
# !bash ./.client/setup.sh # 実行

# モジュールの初期化
exec(open('.client/client_setup.py').read())

# ノートブック固有の設定
NOTEBOOK_PATH = "08_中間テスト/02_ユーザー定義関数.ipynb"
set_notebook_config(NOTEBOOK_PATH)

# %%
#@title 問7 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=7, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題8 関数が呼び出し元に返す値 (3点)
# - 関数が呼び出し元に返す値を何と呼ぶか？
#     📕 1. パラメータ
#     📗 2. 引数
#     📘 3. 戻り値
#     📙 4. 属性

# %%
# 正解を出力してください
print('')

# %%
#@title 問8 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=8, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題9 順序に基づいて渡す引数 (3点)
#
# - 関数呼び出し時に順序に基づいて渡す引数はのことをなんと呼ぶか？
#     📕 1. キーワード引数
#     📗 2. デフォルト引数
#     📘 3. 位置引数
#     📙 4. 可変長引数

# %%
# 正解を出力してください
print('')

# %%
#@title 問9 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=9, button_name="四択問題"))

# %% [markdown]
# ---

# %% [markdown]
# ## 🔰 簡単なプログラムを書く問題

# %% [markdown]
# ### 🔨 問10 (10点)
# 1️⃣ 2つの数値を引数として受け取り、その合計を返す関数 add_numbers を定義してください。
# 2️⃣ その関数を使って、5と7の合計を出力してください。
#
# <!-- PROBLEM_TYPE: SYNTAX_EXERCISE -->

# %%
# Out:
# 12

# %%
#@title 問10 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=10, button_name="問"))

# %% [markdown]
# ### 🗑️ アルゴリズム問題11 要素を削除する関数 (15点)
#
# #### 📝 問題文
#
# - 自然数 N と、長さ N の整数値のリスト A が与えられます。
# - リストの要素は 1 から N まで番号が振られています。
# - 整数値 i (1 ≦ i ≦ N) が与えられるので、リスト A の i 番目の要素を削除し、削除後のリストを出力するプログラムを作成してください。
# - 引数としてリストとリストのインデックスを受け取り、指定されたインデックスの要素を削除する関数 remove_element を定義してください。

# %% [markdown]
# #### 📘 制約
#
# - $ 1 ≦ N ≦ 10^5 (Nは整数) $
# - $ 1 ≦ A[j] ≦ 10^9 (1 ≦ j ≦ N) (A_jは整数) $
# - $ 1 ≦ i ≦ N  (iは整数)$

# %% [markdown]
# #### 🔢 入力
# 入力は以下の形式で標準入力から与えられます
#
# ---
#
# $ N $
# $ A_1, A_2, ...A_N $
# $ i $
#
# ---

# %% [markdown]
# #### 📤 出力
#
# i 番目の要素を削除した後のリストを空白区切りで1行に出力せよ。

# %% [markdown]
# ----
# ----
#
# #### 🧾 入力例1
#
# ---
# ```python
# 5
# 1 2 3 4 5
# 3
# ```
# ---
#
# #### 🧪 出力例1
# ---
# ```python
# 1 2 4 5
# ```
# ---

# %% [markdown]
# ----
# ----
#
# #### 🧾 入力例2
#
# ---
# ```python
# 7
# 10 20 30 40 50 60 70
# 1
# ```
#
# #### 🧪 出力例2
# ---
# ```python
# 20 30 40 50 60 70
# ```
# ---

# %% [markdown]
# ----
# ----
# ### ここ↓にPythonコードを記述してください

# %%
# Out:
#  7
#  10 20 30 40 50 60 70
#  1
# 20 30 40 50 60 70

# %%
#@title 問11 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=11, button_name="アルゴリズム問題"))
