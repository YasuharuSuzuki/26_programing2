# %% [markdown]
# <a href="https://colab.research.google.com/github/YasuharuSuzuki/26_programing2/blob/main/" target="_parent">
# <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🤹🏼 03_関数オブジェクトとクラスの定義に関する問題

# %% [markdown]
# ## 用語の理解を問う問題
# - 以下の問題について、正解となる選択肢を出力してください
# ※4択問題は1回目の回答のみが有効です。何度も提出することは出来ませんので、ご注意ください。

# %% [markdown]
# ### 🎲 四択問題12 各要素に関数を適用する (3点)
# - リストの各要素に対して関数を呼び出す処理を行いたい場合、どの関数を使用すると便利ですか？
#   関数オブジェクトの使用方法として最も適切なものを選んでください
#    📕 1. map()
#    📗 2. filter()
#    📘 3. reduce()
#    📙 4. apply()

# %%
# 正解を出力してください
print('')

# %%
#@title 送信処理用共通プログラム（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown 解答の送信に必要です。（中身は絶対に修正しないでください）

import os
os.makedirs(".client/python", exist_ok=True)  # 隠しフォルダを作成
# !wget -q https://raw.githubusercontent.com/YasuharuSuzuki/26_programing2/main/91_notebook_client/src/setup.sh -O .client/setup.sh   # 外部コードをダウンロードして隠しフォルダに配置
# !chmod +x ./.client/setup.sh
# !bash ./.client/setup.sh # 実行

# モジュールの初期化
exec(open('.client/client_setup.py').read())

# ノートブック固有の設定
NOTEBOOK_PATH = "08_中間テスト/03_関数オブジェクトとクラスの定義.ipynb"
set_notebook_config(NOTEBOOK_PATH)

# %%
#@title 問12 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=12, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題13 無名関数 (3点)
#
# ```python
# numbers = [1, 2, 3, 4, 5]
# even_numbers = list(filter(無名関数 x: x % 2 == 0, numbers))
# print(even_numbers)
# ```
#
# - 上記のコードの出力結果を選択肢の中から選択してください
#   ※ただし、「無名関数」の部分はPythonの無名関数で使用される予約語を使用して動作するようにした上で出力結果を問うこととします
#
#    📕 1. [1, 2, 3, 4, 5]
#    📗 2. [1, 3, 5]
#    📘 3. [2, 4]
#    📙 4. エラーが発生する

# %%
# 正解を出力してください
print('')

# %%
#@title 問13 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=13, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題14 (3点)
# - クラス内で定義された関数を何と呼びますか？
#   最も適切なものを選んでください
#    📕 1. インスタンス
#    📗 2. メソッド
#    📘 3. モジュール
#    📙 4. コンストラクタ

# %%
# 正解を出力してください
print('')

# %%
#@title 問14 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=14, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題15 (3点)
#
# - 実体化されたクラスのことを何と呼びますか？ 最も適切なものを選んでください
#    📕 1. メソッド
#    📗 2. プロパティ
#    📘 3. コンストラクタ
#    📙 4. インスタンス

# %%
# 正解を出力してください
print('')

# %%
#@title 問15 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=15, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## 🧩 プログラムを書く問題

# %% [markdown]
# ### 👨🏻‍🎓 問16 ソートプログラム (20点)
# 以下の要件に従って、Studentクラスを定義し、リストに格納されたStudentオブジェクトを特定の条件でソートするプログラムを作成してください。
#
# 1️⃣ Studentクラスは、name（名前）、gender（性別）、japanese_score（国語の点数）、math_score（数学の点数）の4つのインスタンス変数を持ちます。
# 2️⃣ Studentクラスのコンストラクタは、名前、性別、国語の点数、数学の点数を引数として受け取り、インスタンス変数を初期化します。
# 3️⃣ Studentクラスに、以下の4つのメソッドを定義してください。
#   - get_name(self): Studentオブジェクトの名前を返すメソッド
#   - get_gender(self): Studentオブジェクトの性別を返すメソッド
#   - get_japanese_score(self): Studentオブジェクトの国語の点数を返すメソッド
#   - get_math_score(self): Studentオブジェクトの数学の点数を返すメソッド
#
# 4️⃣ 20名分のStudentオブジェクトをリストに格納してください。適当な名前、性別、国語と数学の点数を割り当ててください。
# 5️⃣ 格納されたStudentオブジェクトのリストから、女性の生徒のみを選択してください。
# 6️⃣ 選択された女性の生徒のリストを、国語と数学の合計点数の降順でソートしてください。
# 7️⃣ ソートされたリストから、上位5名の生徒の名前、性別、国語の点数、数学の点数を取得し、出力してください。
#
# Studentクラスについては、ところどころ未記載の状態で定義したプログラムを以下に記述しておきますので、虫食いを埋める形で記載ください。
# 20名分のStudentオブジェクトは、プログラムを書くのが大変なため記載してあります。そちらを流用する形で使用してください
#
# <!-- PROBLEM_TYPE: SYNTAX_EXERCISE -->

# %%
# クラス定義
class Student:
    def __init__(self, name, gender, japanese_score, math_score):
        self.name = # ここにプログラムを記入して完成させましょう
        self.gender = gender
        self.japanese_score = japanese_score
        self.math_score = math_score
    
    def get_name(self):
        return self.name
    
    def get_gender(self):
        return # ここにプログラムを記入して完成させましょう
    
    def get_japanese_score(self):
        return self.japanese_score
    
    def get_math_score(self):
        return self.math_score
    
    def get_total_score(self):
        return # ここにプログラムを記入して完成させましょう

# %%
# 20名分の学生データ定義（そのままご利用ください)
students = [
    Student("山田花子", "女", 85, 90),
    Student("田中太郎", "男", 80, 85),
    Student("鈴木美香", "女", 90, 95),
    Student("佐藤健司", "男", 75, 80),
    Student("伊藤舞", "女", 94, 90),
    Student("渡辺圭介", "男", 70, 75),
    Student("小林杏奈", "女", 80, 85),
    Student("加藤裕樹", "男", 85, 90),
    Student("山口莉奈", "女", 90, 85),
    Student("木村翔太", "男", 80, 80),
    Student("吉田紗織", "女", 95, 95),
    Student("松本大輝", "男", 75, 70),
    Student("石川結衣", "女", 85, 90),
    Student("中村駿", "男", 90, 85),
    Student("小野寺美咲", "女", 80, 85),
    Student("佐々木翔平", "男", 75, 80),
    Student("原田茜", "女", 90, 93),
    Student("斎藤大樹", "男", 85, 90),
    Student("榎本安奈", "女", 92, 90),
    Student("藤原健太", "男", 80, 85)
]

# %%
# filter関数を使って女性の生徒のみを選択
# ここにプログラムを記入して完成させましょう

# 合計点数の降順でソート
# ここにプログラムを記入して完成させましょう

# %%
# 上位5名の生徒の情報を出力
# ここにプログラムを記入して完成させましょう
# Out:
# 名前: 吉田紗織, 性別: 女, 国語の点数: 95, 数学の点数: 95
# 名前: 鈴木美香, 性別: 女, 国語の点数: 90, 数学の点数: 95
# 名前: 伊藤舞, 性別: 女, 国語の点数: 94, 数学の点数: 90
# 名前: 原田茜, 性別: 女, 国語の点数: 90, 数学の点数: 93
# 名前: 榎本安奈, 性別: 女, 国語の点数: 92, 数学の点数: 90

# %%
#@title 問16 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=16, button_name="問"))
