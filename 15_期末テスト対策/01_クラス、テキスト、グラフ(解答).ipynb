# %% [markdown]
# <a href="https://colab.research.google.com/github/YasuharuSuzuki/26_programing2/blob/main/" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01_クラス、テキスト、グラフ
# ## 🎒 クラスの継承・プロパティの利用に関する問題

# %% [markdown]
# ### 用語の理解を問う問題
# - 以下の問題について、正解となる選択肢を出力してください
# ※4択問題は1回目の回答のみが有効です。何度も提出することは出来ませんので、ご注意ください。

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題1 (3点)
# - 継承元のクラスを何と呼びますか？
#     📕 1. 子クラス
#     📗 2. 派生クラス
#     📘 3. スーパークラス
#     📙 4. サブクラス

# %%
# 正解を出力してください
print('3') # 継承元のクラスは、スーパークラス（あるいは親クラス、基底クラス）と呼ばれます。
# Out:
# 3

# %% [markdown]
# ---
# ### ✅ 解説
# - 正解：📘 3. スーパークラス
#   - 継承元のクラスは **スーパークラス**（親クラス、基底クラス）と呼ばれます。
#   - 継承先の新しいクラスは **サブクラス**（子クラス、派生クラス）と呼ばれ、スーパークラスの機能を受け継ぎます。
#
# #### ❌ 他の選択肢が誤りである理由
# - 📕 1. 子クラスは継承先（サブクラス）を指す用語で、継承元ではありません
# - 📗 2. 派生クラスも継承先（サブクラス）を指す別名であり、継承元ではありません
# - 📙 4. サブクラスは継承先のクラスを指す用語で、継承元とは逆の立場です
# ---

# %%
#@title 送信処理用共通プログラム（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown 解答の送信に必要です。（中身は絶対に修正しないでください）

import os
os.makedirs(".client/python", exist_ok=True)  # 隠しフォルダを作成
# !wget -q https://raw.githubusercontent.com/YasuharuSuzuki/26_programing2/main/91_notebook_client/src/setup.sh -O .client/setup.sh   # 外部コードをダウンロードして隠しフォルダに配置
# !chmod +x ./.client/setup.sh
# !bash ./.client/setup.sh # 実行

# sandbox実行用
# os.symlink("../../src", ".client", target_is_directory=True)
# !bash ./sandbox_setup.sh # 実行

# モジュールの初期化
exec(open('.client/client_setup.py').read())

# ノートブック固有の設定
NOTEBOOK_PATH = "15_期末テスト対策/01_クラス、テキスト、グラフ.ipynb"
set_notebook_config(NOTEBOOK_PATH)

# %%
#@title 問1 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=1, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題2 (3点)
# - プロパティの getter メソッドを定義するためのデコレータは何ですか？
#   📕 1. @setter
#   📗 2. @property
#   📘 3. @getter
#   📙 4. @classmethod

# %%
# 正解を出力してください
print('2')  # @property デコレータは、メソッドをプロパティの getter として定義するために使用されます。
# Out:
# 2

# %% [markdown]
# ---
# ### ✅ 解説
# - 正解：📗 2. @property
#   - Pythonでプロパティのgetterメソッドを定義するには **@property** デコレータを使います。
#   - `@property` を付けたメソッドは、通常のメソッド呼び出し（`obj.method()`）ではなく、属性アクセス（`obj.method`）と同じ書き方で値を取得できるようになります。
#   - このデコレータを使うことで、外部からは普通の属性のように見せつつ、内部ではメソッドとして処理を実行できます（カプセル化に役立ちます）。
#
# #### ❌ 他の選択肢が誤りである理由
# - 📕 1. @setterは、@propertyで定義したgetterに対応するsetter（値を設定するメソッド）を定義する際に使うデコレータで、`@プロパティ名.setter`という形で使用します。getter自体の定義には使いません。
# - 📘 3. @getterというデコレータはPythonに存在しません。
# - 📙 4. @classmethodは、インスタンスではなくクラス自体に紐づくメソッド（クラスメソッド）を定義するためのデコレータで、getterとは無関係です。
# ---

# %%
#@title 問2 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=2, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## 🐣 簡単なプログラムを書く問題

# %% [markdown]
# ### 🚙 問3 (10点)
# 書きかけのプログラムがあります。
# 期待される出力結果は以下のとおりです
#
# ```
# Brand: Toyota
# Model: Corolla
# ```
#
# 出力結果が一致するように`Vehicle` クラスのdisplay_info()にプログラムを1行追加して完成させてください。
#
# <!-- PROBLEM_TYPE: SYNTAX_EXERCISE -->

# %%
class Vehicle:
    def __init__(self, brand):
        self.brand = brand
    
    def display_info(self):
        # ここにプログラムを書きましょう
        print(f"Brand: {self.brand}")

class Car(Vehicle):
    def __init__(self, brand, model):
        super().__init__(brand)
        self.model = model
    
    def display_info(self):
        super().display_info()
        print(f"Model: {self.model}")

# インスタンスの作成と使用
my_car = Car("Toyota", "Corolla")
my_car.display_info()
# Out:
# Brand: Toyota
# Model: Corolla

# %%
#@title 問3 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=3, button_name="問"))

# %% [markdown]
# ---
# ---
# ---
# ---
# ---

# %% [markdown]
# ## 📝 テキストファイルの読み込み、書き出しに関する問題
# ### 用語の理解を問う問題
# - 以下の問題について、正解となる選択肢を出力してください
# ※4択問題は1回目の回答のみが有効です。何度も提出することは出来ませんので、ご注意ください。

# %% [markdown]
# ---

# %% [markdown]
# ### 🎲 四択問題4 ファイル追記モード (3点)
# - ファイルの末尾に新しい内容を追加するモードを以下から選べ
#     📕 1. r
#     📗 2. w
#     📘 3. a
#     📙 4. w+

# %%
# 正解を出力してください
print('3') # 'a' モードは append（追加）の略で、ファイルを追記モードで開きます。このモードでは、ファイルの末尾に新しい内容を追加することができます。既存の内容は変更されません。
# Out:
# 3

# %% [markdown]
# ---
# ### ✅ 解説
# - 正解：📘 3. a
#   - ファイルの末尾に新しい内容を追加（追記）するモードは **`a`**（appendの略）です。
#   - `a`モードでファイルを開くと、既存の内容は保持されたまま、書き込んだデータがファイルの末尾に追加されます。ファイルが存在しない場合は新規作成されます。
#
# #### ❌ 他の選択肢が誤りである理由
# - 📕 1. `r`は読み取り専用モード（read）で、書き込みはできません。
# - 📗 2. `w`は書き込みモード（write）ですが、既存の内容を **上書き（削除）** してから新しく書き込むため、追記にはなりません。
# - 📙 4. `w+`は読み書き両用モードですが、こちらも`w`と同様にファイルを開いた時点で既存の内容が消去されるため、追記モードではありません。
# ---

# %%
#@title 問4 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=4, button_name="四択問題"))

# %% [markdown]
# ### 🔰 簡単なプログラムを書く問題

# %% [markdown]
# ### 問5 (10点)
# `data/kokoro.txt` のファイル内容を読み込んで、そのままprint文で出力するPythonプログラムを作成してください。
#
# <!-- PROBLEM_TYPE: SYNTAX_EXERCISE -->

# %%
# drive.mount()を使用してGoogleDriveをMount
from google.colab import drive
drive.mount('/content/drive')

# %%
# os.chdir()を使用してカレントディレクトリを変更。作成したショーットカット名を使ってパスを指定します。
import os
os.chdir('/content/drive/MyDrive/＜作成したショートカット名＞')

# %%
# ./data/以下のファイルをアップロードしておき、ここでパスを指定します
file_path = "./data/kokoro.txt"

# ファイルを読み込みます
with open(file_path, "r", encoding="utf_8") as fileobj:
    text = fileobj.read()
    print(text)
# Out:
# 私はその人を常に先生と呼んでいた。
# だからここでもただ先生と書くだけで本名は打ち明けない。
# これは世間を憚かる遠慮というよりも、その方が私にとって自然だからである。
# 私はその人の記憶を呼び起こすごとに、すぐ「先生」といいたくなる。
# 筆を執っても心持は同じである。

# %%
#@title 問5 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=5, button_name="問"))

# %% [markdown]
# ---
# ---
# ---
# ---
# ---

# %% [markdown]
# ## 📊 グラフに関する問題

# %% [markdown]
# ### 用語の理解を問う問題
# - 以下の問題について、正解となる選択肢を出力してください

# %% [markdown]
# ---

# %% [markdown]
# ### 🎲 四択問題6 散布図 (3点)
# - matplotlibを使用して、散布図を作成する関数は何ですか？
#     📕 1. plt.scatter()
#     📗 2. plt.dot()
#     📘 3. plt.point()
#     📙 4. plt.spread()

# %%
# 正解を出力してください
print('1') # plt.scatter()関数は、散布図（スキャッタープロット）を作成するために使用されます。
# Out:
# 1

# %% [markdown]
# ---
# ### ✅ 解説
# - 正解：📕 1. plt.scatter()
#   - matplotlibで散布図（scatter plot）を作成するには **`plt.scatter()`** 関数を使用します。
#   - `plt.scatter(x, y)`のようにx軸とy軸のデータを渡すことで、各データ点を座標上にプロットした散布図を描画できます。点の大きさや色なども引数で細かく指定できます。
#
# #### ❌ 他の選択肢が誤りである理由
# - 📗 2. `plt.dot()`という関数はmatplotlibに存在しません（架空の関数名です）。
# - 📘 3. `plt.point()`という関数もmatplotlibには存在しません（架空の関数名です）。
# - 📙 4. `plt.spread()`という関数もmatplotlibには存在しません（架空の関数名です）。
# ---

# %%
#@title 問6 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=6, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題7 X軸ラベル (3点)
# - matplotlibを使用して、グラフを描画する際に x 軸にラベルを追加するための関数は何ですか？
#     📕 1. plt.xlabel()
#     📗 2. plt.xname()
#     📘 3. plt.xtitle()
#     📙 4. plt.xaxis()

# %%
# 正解を出力してください
print('1') # plt.xlabel()関数は、グラフのx軸にラベルを追加するために使用されます。
# Out:
# 1

# %% [markdown]
# ---
# ### ✅ 解説
# - 正解：📕 1. plt.xlabel()
#   - matplotlibでグラフのx軸にラベル（軸名）を追加するには **`plt.xlabel()`** 関数を使用します。
#   - `plt.xlabel("ラベル名")`のように文字列を渡すことで、x軸の下に指定したラベルを表示できます。なお、y軸にラベルを付ける場合は`plt.ylabel()`を使います。
#
# #### ❌ 他の選択肢が誤りである理由
# - 📗 2. `plt.xname()`という関数はmatplotlibに存在しません。
# - 📘 3. `plt.xtitle()`という関数もmatplotlibには存在しません。グラフ全体のタイトルを付ける場合は`plt.title()`を使いますが、これはx軸専用のラベルではありません。
# - 📙 4. `plt.xaxis()`という関数もmatplotlibには存在しません（`ax.xaxis`という属性は存在しますが、ラベルを設定する関数とは異なります）。
# ---

# %%
#@title 問7 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=7, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題8 (3点)
# - 以下のグラフの種類を選べ
#     📕 1. 円グラフ
#     📗 2. 棒グラフ
#     📘 3. 散布図
#     📙 4. 折れ線グラフ
#
# ![グラフ](data/image01.png)

# %%
# 正解を出力してください
print('4')
# Out:
# 4

# %% [markdown]
# ---
# ### ✅ 解説
# - 正解：📙 4. 折れ線グラフ
#   - このグラフは、日付ごとのワクチン接種数の推移を、データ点を線でつないで表示しています。このように時系列データの変化を線で表現するグラフを**折れ線グラフ**と呼びます。
#   - 沖縄県（オレンジ色・丸マーカー）と東京都（青色・三角マーカー）の2つの系列が、それぞれ日ごとの増減の様子を線でつなげて表現されており、時間の経過に伴う変化を視覚的に把握しやすくなっています。
#
# #### ❌ 他の選択肢が誤りである理由
# - 📕 1. 円グラフは、全体に対する割合（内訳）を扇形で表すグラフです。このグラフには割合を示す要素がないため、円グラフではありません。
# - 📗 2. 棒グラフは、各項目の値を棒の長さで比較するグラフです。このグラフにはデータ点を結ぶ線がありますが、棒は使われていないため、棒グラフではありません。
# - 📘 3. 散布図は、2つの変数の関係性を点だけでプロットし、通常は点同士を線で結ばないグラフです。このグラフは点が線で結ばれ推移を示しているため、散布図ではありません。
# ---

# %%
#@title 問8 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=8, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## 🌱 簡単なプログラムを書く問題

# %% [markdown]
# ### 問9 (10点)
# 以下の要件を満たすPythonプログラムを作成してください。
#
# 1. 以下のデータを使用して折れ線グラフを作成してください：
#    x = [1, 2, 3, 4, 5]
#    y = [2, 4, 6, 8, 10]
#
# 2. グラフには以下の要素を含めてください：
#    - タイトル: "Simple Line Graph"
#    - x軸のラベル: "X-axis"
#    - y軸のラベル: "Y-axis"
#    - 青色の線
#    - 赤色の丸いマーカー
#
# 3. グラフを表示してください。
#
# ヒント：
# - Matplotlibライブラリを使用してください。
# - グラフの色やマーカーは、plt.plot()関数のパラメータで指定できます。
#
# <!-- PROBLEM_TYPE: SYNTAX_EXERCISE -->

# %%
# ライブラリのimport
import matplotlib.pyplot as plt

# データの準備
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# グラフの作成
plt.plot(x, y, color='blue', marker='o', markerfacecolor='red', markersize=8)

# タイトルと軸ラベルの設定
plt.title("Simple Line Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# グラフの表示
plt.show()

# %%
#@title 問9 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=9, button_name="問"))
