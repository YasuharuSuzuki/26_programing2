# %% [markdown]
# <a href="https://colab.research.google.com/github/YasuharuSuzuki/26_programing2/blob/main/" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 05_アルゴリズム問題

# %% [markdown]
# ## 🐳 アルゴリズム問題とは

# %% [markdown]
# アルゴリズム問題は、特定の課題や要求に対して、効率的で正確な解決方法（アルゴリズム）を考え、それをプログラムとして実装する問題です。
# 実際のプログラミングの現場で直面する課題をシンプルな形で再現したような問題が多く、パズルを解くような感覚で楽しみながらプログラミングできると習得しやすいです。
# 基本的にはinput()で入力を受け取り、データに対して何らかの処理を加えたあと、print()で出力する流れになります。

# %% [markdown]
# ### 💁‍♀️ 例題
# ## 🔰 5をかけてください

# %% [markdown]
# - 数値 N が与えられます。
# - 5倍した数 5*N を出力して下さい。

# %% [markdown]
# ### 📘 制約
# $
# 1 \leq N \leq 10^{10} (Nは整数) \\
# $

# %% [markdown]
# ### 🔢 入力
# 入力は以下の形式で標準入力から与えられます
#
# ---
# $
# N  \\
# $
#
# ---

# %% [markdown]
# ### 📤 出力
#
# ---
# 5倍した数
#
# ---
# 5倍した数を出力して下さい。

# %% [markdown]
# ----
# ----
#
# ### 🧾 入力例1
# ---
# ```python
# 123456789
# ```
# ---
#
# ### 🧪 出力例1
# ---
# ```python
# 617283945
# ```
# ---
# ※ 123456789の5倍の数として 617283945 を出力します

# %% [markdown]
# ----
# ----
#
# ### 🧾 入力例2
# ---
# ```python
# 5
# ```
# ---
#
# ### 🧪 出力例2
# ---
# ```python
# 25
# ```
# ---
# ※ 5の5倍の数は25ですので、 25 を出力します

# %% [markdown]
# ----
# ----
#
# ### 🧾 入力例3
# ---
# ```python
# 99999999
# ```
# ---
#
# ### 🧪 出力例3
# ---
# ```python
# 499999995
# ```
# ---
# ※ 99999999 の5倍の数は 499999995 のため、 499999995 を出力してください。

# %% [markdown]
# ----
# ----
# ### ここ↓にPythonコードを記述してください

# %%
# 1. 入力を受け取ります
N = int(input())

# 2. 処理を行います
N = N * 5

# 3. 出力します
print(N)
# Out:
# 25

# %% [markdown]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----

# %% [markdown]
# ### 🧮 アルゴリズム問題11 わり算するといくつになるかな？ (8点)
#
# #### 📝 問題文
# - ゆるるくんは小学3年生向けの問題を作成しています。
# - 割り算の結果を自動的に求めるプログラムを作成し、小学生に見せたいと思っています。
# - 元の数を $ A $、割る数を $ B $ とし、商を $ D $ 、余りを $ R $としたとき、 以下の２行の文字列で表示するプログラムを作成してください。
#   - $ A $ ÷ $ B $ = $ D $ あまり $ R $
#   - 答えは $ D $ あまり $ R $ です

# %% [markdown]
# #### 📘 制約
# $ 1 \leq　A \leq　99 $
# $ 1 \leq　B \leq　9 $
# $ 1 \leq　D \leq　9 $
# $ 0 \leq　R \leq　8 $
# $ A $、 $ B $、 $ D $、 $ R $ は整数

# %% [markdown]
# #### 🔢 入力
# 入力は以下の形式で標準入力から与えられます
#
# ---
# $ A \quad B $
#
# ---
#
# 元の数 $ A $、割る数 $ B $ を空白区切りで受け取ります

# %% [markdown]
# #### 📤 出力
#
# ---
# $ A $ ÷ $ B $ = $ D $ あまり $ R $
# 答えは $ D $ あまり $ R $ です
#
# ---
#
# わり算の結果を、式と答えの２行の文章に分けて出力してください。

# %% [markdown]
# ----
# ----
#
# #### 🧾 入力例1
# ---
# ```python
# 35  4
# ```
# ---
#
# #### 🧪 出力例1
# ---
# ```python
# 35 ÷ 4 = 8 あまり 3
# 答えは 8 あまり 3 です
# ```
# ---
# - 式「35 ÷ 4 = 8 あまり 3」と、答え「答えは 8 あまり 3 です」の２行の文章に分けて出力します。

# %% [markdown]
# ----
# ----
#
# #### 🧾 入力例2
# ---
# ```python
# 67  9
# ```
# ---
#
# #### 🧪 出力例2
# ---
# ```python
# 67 ÷ 9 = 7 あまり 4
# 答えは 7 あまり 4 です
# ```
# ---
# - 式「67 ÷ 9 = 7 あまり 4」と、答え「答えは 7 あまり 4 です」の２行の文章に分けて出力します。

# %% [markdown]
# ----
# ----
# ### ここ↓にPythonコードを記述してください

# %%
#@title 送信処理用共通プログラム（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown 解答の送信に必要です。（中身は絶対に修正しないでください）

import os
os.makedirs(".client/python", exist_ok=True)  # 隠しフォルダを作成
# !wget -q https://raw.githubusercontent.com/YasuharuSuzuki/26_programing2/main/91_notebook_client/src/setup.sh -O .client/setup.sh   # 外部コードをダウンロードして隠しフォルダに配置
# !chmod +x ./.client/setup.sh
# !bash ./.client/setup.sh # 実行

# モジュールの初期化
exec(open('.client/client_setup.py').read())

# ノートブック固有の設定
NOTEBOOK_PATH = "01_Python復習1/05_アルゴリズム問題.ipynb"
set_notebook_config(NOTEBOOK_PATH)

# %%
#@title 問11 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=11, button_name="アルゴリズム問題"))

# %% [markdown]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----

# %% [markdown]
# ### 🎡 アルゴリズム問題12 ゆるるパーク (8点)
#
# #### 📝 問題文
# - あなたは、「ゆるるパーク」というテーマパークのチケット販売システムを開発することになりました。
# - このテーマパークでは、年齢に応じて料金が異なります。
# - 以下の料金体系に基づいて、入力された大人の料金 $ A $ と年齢 $ N $ に対する料金 $ R $ を計算するプログラムを作成してください。
#   - 0歳から5歳までは無料
#   - 6歳から12歳までは半額（大人料金の50%）
#   - 13歳から64歳までは大人料金
#   - 65歳以上は敬老割引（大人料金の70%）

# %% [markdown]
# #### 📘 制約
#
# $ 1000 \leq　A \leq　10000 $
# $ 0 \leq　N \leq　120 $
# $ 0 \leq　R \leq　10000 $
#
# $ A $、$ N $、$ R $ はそれぞれ整数
# $ R $ は小数点以下切り捨て

# %% [markdown]
# #### 🔢 入力
# 入力は以下の形式で標準入力から与えられます
#
# ---
# $
# A \quad N \\
# $
#
# ---
#
# Aは整数で、大人の料金を表します。
# Nは整数で、入力される年齢を表します。

# %% [markdown]
# #### 📤 出力
#
# ---
# $ R $
#
# ---
#
# 料金 $ R $ を出力してください。

# %% [markdown]
# ----
# ----
#
# ### 🧾 入力例1
# ----
# ```python
# 1000 3
# ```
# ----
#
# ### 🧪 出力例1
# ----
# ```python
# 0
# ```
# ----
# - 3歳児の料金は0円です

# %% [markdown]
# ----
# ----
#
# ### 🧾 入力例2
# ----
# ```python
# 1500 10
# ```
# ----
#
# ### 🧪 出力例2
# ----
# ```python
# 750
# ```
# ----
# - 10歳では半額になります

# %% [markdown]
# ----
# ----
#
# ### 🧾 入力例3
# ----
# ```python
# 2000 25
# ```
# ----
#
# ### 🧪 出力例3
# ----
# ```python
# 2000
# ```
# ----
# - 25歳は割引なしです

# %% [markdown]
# ----
# ----
#
# ### 🧾 入力例4
# ----
# ```python
# 1200 70
# ```
# ----
#
# ### 🧪 出力例4
# ----
# ```python
# 840
# ```
# ----
# - 70歳は3割引です

# %% [markdown]
# ----
# ----
#
# ### ここ↓にPythonコードを記述してください

# %%
# Out:
# 840

# %%
#@title 問12 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=12, button_name="アルゴリズム問題"))

# %% [markdown]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----

# %% [markdown]
# ### 🍣 アルゴリズム問題13 ゆるる寿司 (15点)
#
# #### 📝 問題文
# - あなたは、「ゆるる寿司」という回転寿司屋でたくさんの寿司を食べました。
# - 食べた寿司ネタの値段 $ P_i $ が整数のリストで与えられるので、合計金額 $ R $ を求めるプログラムを作成してください。

# %% [markdown]
# #### 📘 制約
#
# $ 1 \leq N \leq 100 $
# $ 1 \leq P_i \leq 1000 $

# %% [markdown]
# #### 🔢 入力
# 入力は以下の形式で標準入力から与えられます
#
# ---
# $ N $
# $ P_1 \quad P_2 \quad ... \quad P_N $
#
# ---

# %% [markdown]
# #### 📤 出力
#
# ---
# $ R $
#
# ---
# 食べた寿司ネタの合計金額を出力してください。

# %% [markdown]
# ----
# ----
#
# #### 🧾 入力例1
# ---
# ```python
# 5
# 100 150 200 120 180
# ```
# ---
#
#
# #### 🧪 出力例1
# ---
# ```python
# 750
# ```
# ---

# %% [markdown]
# ----
# ----
#
# #### 🧾 入力例2
# ---
# ```python
# 8
# 100 50 80 120 150 200 300 400
# ```
# ---
#
#
# #### 🧪 出力例2
# ---
# ```python
# 1400
# ```
# ---

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### ここ↓にPythonコードを記述してください

# %%
# Out:
# 150

# %%
#@title 問13 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=13, button_name="アルゴリズム問題"))

# %% [markdown]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----

# %% [markdown]
# ### 🍬 アルゴリズム問題14 駄菓子屋AVG (15点)

# %% [markdown]
# #### 📝 問題文
# - ゆるるくんは駄菓子屋へ行きました。
# - 雑多に置かれた駄菓子を $ N $ 個掴みましたが、そのうちの $ S $ 番目〜 $ E $ 番目までを買うことにしました。
# - 各駄菓子の値段が $ D_1 $ 〜 $ D_N $ で表される時、駄菓子の平均金額 $ A $ を出力せよ

# %% [markdown]
# #### 📘 制約
# $ 1 \leq　N \leq　10 $
# $ 1 \leq　S \leq　N $
# $ S \leq　E \leq　N $
# $ 5 \leq　D_i \leq　100 $
# $ 5.0 \leq　A \leq　100.0 $
# $ N $、$ S $、$ E $ 、$ D_i $ はそれぞれ整数
#
# $ A $ は小数点第一位まで出力
# - 小数点第二位以下は丸めてください。
# - 小数点以下は適切な桁数で表示が丸まっていればOKとします。formatやfstringの桁数指定を使用してください。
# - 厳密な四捨五入かどうかは問わないこととします(Pythonで四捨五入するのは難しいため）

# %% [markdown]
# #### 🔢 入力
# 入力は以下の形式で標準入力から与えられます
#
# ---
#
# $ N \quad S \quad E $
# $ D_1 \quad D_2 \quad ... \quad D_N $
#
# ---
#
# １行目で掴んだ駄菓子の個数$ N $、買うことにした範囲（$ S $、$ E $）を受け取ります。
# ２行目では各駄菓子の値段 $ D_1 $ 〜 $ D_N $ を受け取ります。

# %% [markdown]
# #### 📤 出力
#
# ---
# $ A $
#
# ---
# 駄菓子の平均金額 $ A $ を出力してください。

# %% [markdown]
# ----
# ----

# %% [markdown]
# #### 🧾 入力例1
# ---
# ```python
# 10 1 5
# 5 10 15 20 25 30 35 40 45 50
# ```
# ---
# - １行目で掴んだ駄菓子の個数$ N=10 $、買うことにした範囲（$ S=1 $、$ E=5 $）を受け取ります。
# - ２行目では各駄菓子の値段 $ D_1=5 $ 〜 $ D_{10}=50 $ を受け取ります。
#
# #### 🧪 出力例1
# ---
# ```python
# 15.0
# ```
# ---
#
# - $ D_1 $ 〜 $ D_{5} $ の合計値は $ 75 $です。
#   - $ 5+10+15+20+25 = 75 $
# - 掴んだ駄菓子の数は $5$ になります。
#   - $ E(5)-S(1)+1 = 5 $
# - 合計値を駄菓子の個数で割り算し、平均値は$15.0$となります。

# %% [markdown]
# ----
# ----
#
# #### 🧾 入力例2
# ---
# ```python
# 5 2 4
# 60 70 80 90 100
# ```
# ---
# - １行目で掴んだ駄菓子の個数$ N=5 $、買うことにした範囲（$ S=2 $、$ E=4 $）を受け取ります。
# - ２行目では各駄菓子の値段 $ D_1=60 $ 〜 $ D_{5}=100 $ を受け取ります。
#
# #### 🧪 出力例2
# ---
# ```python
# 80.0
# ```
# ---
# - $ D_2 $ 〜 $ D_{4} $ の合計値は $ 240 $です。
#   - $ 70+80+90 = 240 $
# - 掴んだ駄菓子の数は $3$ になります。
#   - $ E(4)-S(2)+1 = 3 $
# - 合計値を駄菓子の個数で割り算し、平均値は$80.0$となります。

# %% [markdown]
# ----
# ----
#
# #### 🧾 入力例3
# ---
# ```python
# 9 3 5
# 50 50 100 100 51 60 10 5 5
# ```
# ---
# - １行目で掴んだ駄菓子の個数$ N=9 $、買うことにした範囲（$ S=3 $、$ E=5 $）を受け取ります。
# - ２行目では各駄菓子の値段 $ D_{1}=50 $ 〜 $ D_{9}=5 $ を受け取ります。
#
# #### 🧪 出力例3
# ---
# ```python
# 83.7
# ```
# ---
# - $ D_{3} $ 〜 $ D_{5} $ の合計値は $ 251 $です。
#   - $ 100+100+51 = 251 $
# - 掴んだ駄菓子の数は $3$ になります。
#   - $ E(5)-S(3)+1 = 3 $
# - 合計値を駄菓子の個数で割り算し、平均値は$83.66666666666667$となりますが、制約に記載の通り小数点第一位までに丸めて $83.7$ (小数点第二位以下は丸め) を出力します。
#   - ヒント：表示にはformatまたはfstringの桁数指定等を使いましょう

# %% [markdown]
# ----
# ----
#
# ### ここ↓にPythonコードを記述してください

# %%
# Out:
# 83.7

# %%
#@title 問14 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=14, button_name="アルゴリズム問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## さらに得点をゲットするには・・・！

# %% [markdown]
# ### AtCoderによる加点
# - AtCoderのバチャコンやコンテストを解くと最大で3点まで加点されます
# - コーディング力もかなり向上するので一石二鳥でお得です！
# - 提出方法などわからないところはアシスタントの学生さんに聞いて、提出しましょう

# %% [markdown]
# <img src="https://img.atcoder.jp/assets/top/img/logo_bk.svg" width="500" height="400" style="padding: 10px;">

# %% [markdown]
# ### 送付例
# 以下のような情報をテキストに記載してください（提出例）
#
# ```
# Hugkunバチャコン 2025/4/3
# https://kenkoooo.com/atcoder/#/contest/show/a65f53a7-a5ef-486e-988b-feed98ef1f84
#
# AtCoder Beginner Contest
# https://atcoder.jp/contests/abc400
#
# ユーザープロフィール
# https://atcoder.jp/users/shugo743
# ```
# ※２つ以上のバチャコン/コンテストに参加している場合は上記のようにURLを２つお送りください

# %% [markdown]
# ### 制約
#
# - バチャコンの参加期限は１週間です。１問につき課題点として１点ずつ加点します。（ACのみ対象）
# - １つの授業課題につき３問までを加点対象とします。（最大３点まで貰えます）

# %% [markdown]
# ### なぜAtCoderで加点するのか
#
# - 形式としてはアルゴリズム問題に近く、プログラミングの能力を向上させる効果があります
# - 課題と違って即座に自動で正解・不正解が判明するので非常に効率の良い練習ができます
# - 正解が出たら加点しますので、URLをお送りください
# - 問題内容としてはアルゴリズム問題の易しめの問題が1～2問、難しい問題と同じぐらいの難易度の問題が1～2問出ます
#   - AtCoderで `A問題` と言われる問題を中心に解きましょう。 `B問題`は解ける方がいるかもしれませんが、`C問題`以降は初心者にはほとんど無理です。
#   - もっと難しい問題もありますが、そちらはやらなくて良いです（プロのエンジニアでも解くのが難しい問題がたくさん出ます）。

# %% [markdown]
# ### お得情報
#
# - 例年、プログラミングⅡで高得点を取る方は以下の傾向があります
#   - アルゴリズム問題をきちんと解いてた人は点数が高いです（当たり前ですが）
#   - AtCoderにトライいただいている方も総じて高得点です（数は少ないのですが、効果てきめんなので良い成績に結びつく方が多いです）
#   - 予習している方（前日までに課題を提出している）も高得点が多いです（これは指摘された減点内容を再提出することによって加点している効果が大きいです）
#   - まわりの人とわいわい話しながら問題を解いている（自分たちで考える力が身につきます。ただしコピペは実力つかないので辞めましょうね）
#   - できるかぎり自分の力で解きつつ、わからないところは放置せずにアシスタントや講師に質問している（出来ない問題を出来ないままにする人は点数が低い方が多いです）
#
# - プログラミングⅡで秀を取られた方は、毎回AtCoderを提出していた方が多くいました
#   - 加点になるのに加えて実力もつきますので、ぜひチャレンジしましょう
