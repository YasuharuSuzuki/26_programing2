# %% [markdown]
# <a href="https://colab.research.google.com/github/YasuharuSuzuki/26_programing2/blob/main/" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 👨🏻‍💻　Section 5 ユーザー定義関数

# %% [markdown]
# ---
# ### 🌐 関数 参考サイト
# #### [参考サイト1【Python早見表】関数](https://chokkan.github.io/python/04function.html)
# #### [参考サイト2【Python入門】関数](https://utokyo-ipp.github.io/3/3-3.html)

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### ◌ サンプルプログラム４　戻り値がない関数
# - 2個のサイコロを振り、大きい方を結果を表示する関数
# - 引数なし、戻り値なしの関数を作る

# %%
from random import randint

# サイコロを振る関数の定義
def dice():
    result = randint(1, 6)
    return result

# 2個のサイコロを振って、大きい方を勝ちとして表示するシンプルな関数の定義
def dicegame():
    dice1 = dice() # 1個めのサイコロを振る
    dice2 = dice() # 2個めのサイコロを振る

    print(f"dice1={dice1}, dice2={dice2}")
    print('引き分け' if dice1 == dice2 else "1個めの勝ち" if dice1 > dice2 else "2個めの勝ち")

# 関数の呼び出し
dicegame()
# Out:
# dice1=1, dice2=6
# 2個めの勝ち

# %% [markdown]
# ---

# %% [markdown]
# ### 👑 練習プログラム4 (8点)
# - じゃんけんの"グー","チョキ","パー"のいずれかをランダムで返す関数を2回呼び出して、勝者を表示する関数を作成し、呼び出してみましょう。
# - 戻り値がない関数を１つ以上作成してみましょう。
#
# <!-- PROBLEM_TYPE: SYNTAX_EXERCISE -->

# %%
# 1. じゃんけんの"グー","チョキ","パー"のいずれかをランダムで返す関数を2回呼び出して、勝者を表示する関数を作成して、呼び出してみましょう

import random

def janken():
    hands = ["グー", "チョキ", "パー"]
    return random.choice(hands)

# 正答例
def play_janken():
    player1 = janken()
    player2 = janken()
    
    print(f"プレイヤー1: {player1}")
    print(f"プレイヤー2: {player2}")
    
    if player1 == player2:
        print("引き分けです！")
    elif (player1 == "グー" and player2 == "チョキ") or (player1 == "チョキ" and player2 == "パー") or (player1 == "パー" and player2 == "グー"):
        print("プレイヤー1の勝利！")
    else:
        print("プレイヤー2の勝利！")

# 関数の呼び出し
play_janken()
# Out:
# プレイヤー1: グー
# プレイヤー2: パー
# プレイヤー2の勝利！

# %%
#@title 送信処理用共通プログラム（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown 解答の送信に必要です。（中身は絶対に修正しないでください）

import os
os.makedirs(".client/python", exist_ok=True)  # 隠しフォルダを作成
# !wget -q https://raw.githubusercontent.com/YasuharuSuzuki/26_programing2/main/91_notebook_client/src/setup.sh -O .client/setup.sh   # 外部コードをダウンロードして隠しフォルダに配置
# !chmod +x ./.client/setup.sh
# !bash ./.client/setup.sh # 実行

# sandbox実行用
# os.symlink("../../src", ".client", target_is_directory=True)
# !bash ./sandbox_setup.sh # 実行

# モジュールの初期化
exec(open('.client/client_setup.py').read())

# ノートブック固有の設定
NOTEBOOK_PATH = "05_ユーザー定義関数/03_戻り値がない関数.ipynb"
set_notebook_config(NOTEBOOK_PATH)

# %%
#@title 問4 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=4, button_name="練習プログラム"))

# %% [markdown]
# ---
# ---
# ---
# ---
# ---

# %% [markdown]
# ### ↩️ サンプルプログラム5　関数を途中で抜ける
#
# - return を使って関数を途中で抜ける
# - 引数が数字でない時は処理を中断する関数

# %%
# 引数が数字でない時は処理を中断するシンプルな関数の定義
def calc_price(count):
    if not count.isdigit():
        return None
    unit_price = 50
    price = int(count) * unit_price
    return price

print("金額＝" + str(calc_price(input("購入する個数を入力してください: "))))
# Out:
# 購入する個数を入力してください:  15
# 金額＝750

# %% [markdown]
# ---

# %% [markdown]
# ### ↻ 練習プログラム5 (4点)
#
# - 引数が数字の時は処理を中断してNoneを返す関数を作成し、呼び出してみましょう
#
# <!-- PROBLEM_TYPE: SYNTAX_EXERCISE -->

# %%
# 1. 引数が文字列でない時は処理を中断する関数を作成し、呼び出してみましょう

# 正答例
def process_string(input_str):
    # 入力された文字列が数字であるかどうかを判定する関数を使用して、数字だった場合は”文字列でない”としてNoneを返す
    if input_str.isdigit():
        return None

    # 上記以外にも文字列以外のObjectを受け取っている場合は、Noneを返す (isdigit()を呼び出しているので文字列以外はここには来ないはずだが、念のため)
    if not isinstance(input_str, str):
        return None

    # 文字列として確定したので、戻り値で値を返す
    return input_str

print("処理結果: " + str(process_string(input("数値以外の文字列を入力してください: "))))
# Out:
# 文字列を入力してください:  20
# 入力された文字列: None

# %%
#@title 問5 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=5, button_name="練習プログラム"))

# %% [markdown]
# ---
# ---
# ---
# ---
# ---

# %% [markdown]
# ### 𖦏 サンプルプログラム6　関数で使う変数の有効範囲

# %%
# サンプルプログラム５の関数内で使用したunit_priceを参照してみる
print(unit_price)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # サンプルプログラム３の関数内で使用したunit_priceを参照してみる
# ----> 2 print(unit_price)
#
# NameError: name 'unit_price' is not defined

# %% [markdown]
# - エラーになります
#   - NameError: name 'unit_price' is not defined は　’unit_price’は定義されていません の意味になります
# - 関数定義は閉じた空間になっており、その中で定義されている変数等は関数外から参照することはできません
#   - 関数内で定義された変数を「ローカル変数」といいます。

# %% [markdown]
# ---

# %% [markdown]
# ### 🎯 練習プログラム6 (4点)
#
# - 練習プログラム内のオリジナルで作成した関数内で定義した変数を参照して、エラーを起こしてみましょう。題材は何でも良いです。
#
# <!-- PROBLEM_TYPE: SYNTAX_EXERCISE -->

# %%
# 1. これまで練習プログラム内のオリジナルで作成した関数内で定義した変数を参照して、エラーを起こしてみましょう

# 正答例
print(input_str)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       1 # 1. これまで練習プログラム内のオリジナルで作成した関数内で定義した変数を参照して、エラーを起こしてみましょう
#       2
#       3 # 正答例
# ----> 4 print(input_str)
#
# NameError: name 'input_str' is not defined

# %%
#@title 問6 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=6, button_name="練習プログラム"))
