# %% [markdown]
# <a href="https://colab.research.google.com/github/YasuharuSuzuki/26_programing2/blob/main/" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 👨🏻‍💻 Section 5 ユーザー定義関数
# ## 📌 Section 5-4 位置引数とキーワード引数
# - 位置引数：渡す順番で意味が決まる引数です。記述がシンプルになるため、引数の数が少なく順番が明確な場合に簡潔に値を渡せる引数のことです。
# - キーワード引数：引数名を指定して渡す引数です。引数名を明示して値を渡せるため、順番を気にせず呼び出せて可読性が上がる引数のことです。

# %% [markdown]
# ---

# %% [markdown]
# ### 🌐 関数 参考サイト
# #### [参考サイト1【Python早見表】関数](https://chokkan.github.io/python/04function.html)
# #### [参考サイト2【Python入門】関数](https://utokyo-ipp.github.io/3/3-3.html)

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 📍 サンプルプログラム７　位置引数とキーワード引数
# #### 位置引数
# 1️⃣ Pythonでは、関数の引数にはいくつかの種類がありますが、その中でも位置引数（positional arguments）は最も一般的な引数の形式です。
# 2️⃣ 位置引数は、関数に渡される引数が、関数定義で指定された順序に従って渡されることを意味します。
# 3️⃣ これにより、関数は引数の位置に基づいて、どの引数がどのパラメータに対応するかを決定します。

# %% [markdown]
# #### 以下に、位置引数を使用した関数の例を示します。

# %%
def greet(name, greeting):
    return f"{greeting}, {name}!"

message = greet("John", "Hello")
print(message)  # 出力：Hello, John!
# Out:
# Hello, John!

# %% [markdown]
# - この例では、`greet` という名前の関数を定義し、2つの位置引数 `name` と `greeting` を受け取ります。関数を呼び出す際に、`greet("John", "Hello")` のようにして引数を渡しています。
# - この場合、`"John"` は `name` に、`"Hello"` は `greeting` にそれぞれ対応します。

# %% [markdown]
# #### 位置引数の注意点
# - 位置引数を使用する際には、関数呼び出し時に引数の順序を正確に指定する必要があります。
# - もし引数の順序が間違っていると、意図しない動作やエラーが発生する可能性があります。

# %% [markdown]
# #### 引数の順序を間違えた例

# %%
message = greet("Hello", "John")
print(message)  # 出力：John, Hello! （意図しない結果）
# Out:
# John, Hello!

# %% [markdown]
# #### キーワード引数
# 1️⃣ Pythonのキーワード引数（keyword arguments）は、関数の引数を名前と値のペアで指定することができる引数の形式です。
# 2️⃣ キーワード引数を使用することで、関数呼び出し時に引数の順序を気にせず、引数名を明示的に指定して値を渡すことができます。
# 3️⃣ これにより、コードの可読性が向上し、引数の順序によるエラーを防ぐことができます。

# %% [markdown]
# #### 以下に、キーワード引数を使用した関数の例を示します。

# %%
message = greet(name="John", greeting="Hello")
print(message)  # 出力：Hello, John!
# Out:
# Hello, John!

# %% [markdown]
# - この例では、関数を呼び出す際に、`greet(name="John", greeting="Hello")` のようにして引数名を明示的に指定し、値を渡しています。
# - キーワード引数を使用する場合、引数の順序は関係なくなります。
#
# #### 引数の順序を変更しても、期待通りの結果が得られます。

# %%
message = greet(greeting="Hello", name="John")
print(message)  # 出力：Hello, John!
# Out:
# Hello, John!

# %% [markdown]
# ###  デフォルト引数(初期値がある引数)
# 1️⃣ また、関数定義時にデフォルト値を設定することで、引数が省略された場合にデフォルト値を使用することができます。
# 2️⃣ これにより、関数の柔軟性が向上します。

# %% [markdown]
# #### 以下に、デフォルト引数を使用した関数の例を示します。

# %%
def greet2(name, greeting="Hello"):
    return f"{greeting}, {name}!"

message = greet2(name="John")
print(message)  # 出力：Hello, John!
# Out:
# Hello, John!

# %% [markdown]
# - この例では、`greeting` 引数にデフォルト値 `"Hello"` を設定しています。
# - そのため、`greeting` 引数を省略しても、デフォルト値が使用され、期待通りの結果が得られます。

# %% [markdown]
# ---

# %% [markdown]
# ### 練習プログラム7 (16点)
# 1️⃣ デフォルト引数のある関数を作成してみましょう。題材は何でも良いです。
# 2️⃣ 作成した関数を位置引数を使用して呼び出してみましょう
# 3️⃣ 作成した関数をキーワード引数を使用して呼び出してみましょう
# 4️⃣ 初期値のある引数を省略して関数を呼び出してみましょう
#
# <!-- PROBLEM_TYPE: SYNTAX_EXERCISE -->

# %%
# 1. デフォルト引数のある関数を作成してみましょう
# 作成する関数は何でも良いですが、このNotebookのサンプルプログラムとは違う独自の値を入れましょう
# 変数名も独自のものに変えましょう

# %%
# 2. 作成した関数を位置引数を使用して呼び出してみましょう
# Out:
# 合計金額（税率10%）: 550.0

# %%
# 3. 作成した関数をキーワード引数を使用して呼び出してみましょう
# Out:
# 合計金額（税率10%）: 550.0

# %%
# 4. 初期値のある引数を省略して関数を呼び出してみましょう
# Out:
# 合計金額（デフォルトの税率）: 545.0

# %%
#@title 送信処理用共通プログラム（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown 解答の送信に必要です。（中身は絶対に修正しないでください）

import os
os.makedirs(".client/python", exist_ok=True)  # 隠しフォルダを作成
# !wget -q https://raw.githubusercontent.com/YasuharuSuzuki/26_programing2/main/91_notebook_client/src/setup.sh -O .client/setup.sh   # 外部コードをダウンロードして隠しフォルダに配置
# !chmod +x ./.client/setup.sh
# !bash ./.client/setup.sh # 実行

# モジュールの初期化
exec(open('.client/client_setup.py').read())

# ノートブック固有の設定
NOTEBOOK_PATH = "05_ユーザー定義関数/04_位置引数とキーワード引数.ipynb"
set_notebook_config(NOTEBOOK_PATH)

# %%
#@title 問7 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=7, button_name="練習プログラム"))
