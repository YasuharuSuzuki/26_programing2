# %% [markdown]
# <a href="https://colab.research.google.com/github/YasuharuSuzuki/26_programing2/blob/main/" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Section 4-1 辞書
# - Pythonの辞書（dictionary）は、キー（key）と値（value）のペアを格納するデータ構造です。

# %% [markdown]
# ----
#
# #### 🤓 雑学
# - キーを指定すると値が取り出せるシンプルなデータ構造は、KVS（KeyValueStore）もしくは単にKeyValueと呼ばれることがあります
#   - memcashedやredis、ドキュメント型データベースでよく使われますね
# - 異なるプログラミング言語で言いますと、PHPでは連想配列、Javaではハッシュマップとそれぞれ名前は違いますが、仕組みとしてはほぼ同じ仕組みです

# %% [markdown]
# ---
#
# ### 🌐 辞書 参考サイト
# #### [参考サイト1【Python早見表】辞書](https://chokkan.github.io/python/09dict.html)
#
# #### [参考サイト2【Python入門】辞書](https://utokyo-ipp.github.io/3/3-1.html)

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## 📓 サンプルプログラム1　辞書を作る
# ### 🌱 コロン区切りでキーと値のペアを定義し、大かっこ { } で括って辞書を作る
# - コロン区切りでキーと値のペアを定義し、大かっこ { } で括って辞書を作ります

# %%
# 辞書の作成
# コロン区切りでキーと値のペアを定義し、カンマで区切り、大かっこ { } で括って辞書を作ります
prefecture_type = {1:"北海道", 2:"青森県", 3:"岩手県", 47:"沖縄県"}
prefecture_type
# Out:
# {1: '北海道', 2: '青森県', 3: '岩手県', 47: '沖縄県'}

# %%
# キーには文字列を使うことができます。
region_map = {"北海道":"北海道地方", "青森県":"東北地方", "岩手県":"東北地方", "沖縄県":"九州地方"}
region_map
# Out:
# {'北海道': '北海道地方', '青森県': '東北地方', '岩手県': '東北地方', '沖縄県': '九州地方'}

# %% [markdown]
# - 数字と文字列を混在させることも可能です。
# - key&valueを,で区切って並べ、全体を{ }で囲んで作成します。

# %% [markdown]
# ### 📊 要素の数を確認する
# - len()を使います
# - リストやタプルと同じですね

# %%
print('len(prefecture_type)=',len(prefecture_type))
print('len(region_map)=',len(region_map))
# Out:
# len(prefecture_type)= 4
# len(region_map)= 4

# %% [markdown]
# ### ◌ 空のdictを作る
# - { } または dict() で作ります

# %%
empty_dict = dict()
empty_dict
# Out:
# {}

# %% [markdown]
# ## 📚 練習プログラム1 (12点)
# 1️⃣ dictを作成してみましょう。題材は何でも良いです。
# 2️⃣ dictの要素の数を出力してみましょう
# 3️⃣ 空のdictを作成してみましょう

# %%
# 1. dictを作成してみましょう
# 入れる値は何でも良いですが、このNotebookのサンプルプログラムとは違う独自の値を入れましょう
# 変数名も独自のものに変えましょう

# ここにPythonプログラムを記述してください

# %%
# 2.  dictの要素の数を出力してみましょう

# ここにPythonプログラムを記述してください

# %%
# 3. 空のdictを作成してみましょう
# 入れる値は何でも良いですが、このNotebookのサンプルプログラムとは違う独自の値を入れましょう
# 変数名も独自のものに変えましょう

# ここにPythonプログラムを記述してください

# %%
#@title 送信処理用共通プログラム（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown 解答の送信に必要です。（中身は絶対に修正しないでください）

import os
os.makedirs(".client/python", exist_ok=True)  # 隠しフォルダを作成
# !wget -q https://raw.githubusercontent.com/YasuharuSuzuki/26_programing2/main/91_notebook_client/src/setup.sh -O .client/setup.sh   # 外部コードをダウンロードして隠しフォルダに配置
# !chmod +x ./.client/setup.sh
# !bash ./.client/setup.sh # 実行

# モジュールの初期化
exec(open('.client/client_setup.py').read())

# ノートブック固有の設定
NOTEBOOK_PATH = "04_辞書/01_辞書を作る.ipynb"
set_notebook_config(NOTEBOOK_PATH)

# %%
#@title 問1 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=1, button_name="練習プログラム"))

# %% [markdown]
# ---

# %% [markdown]
# ## 🛠️ サンプルプログラム2　dictの要素の追加・更新

# %% [markdown]
# ### 要素の追加・更新
# - キーを指定して値を代入する形で要素を追加、または更新できます

# %%
prefecture_type[4] = '宮城県'
prefecture_type
# Out:
# {1: '北海道', 2: '青森県', 3: '岩手県', 47: '沖縄県', 4: '宮城県'}

# %% [markdown]
# - キーがない時は追加

# %%
prefecture_type[47] = '琉球'
prefecture_type
# Out:
# {1: '北海道', 2: '青森県', 3: '岩手県', 47: '琉球', 4: '宮城県'}

# %% [markdown]
# - キーがある時は更新

# %% [markdown]
# ## 🔰　練習プログラム2 (8点)
# 1️⃣ dictの要素を追加してみましょう。題材は何でも良いです。
# 2️⃣ dictの要素を更新してみましょう

# %%
# 1. dictの要素を追加してみましょう
# 入れる値は何でも良いですが、このNotebookのサンプルプログラムとは違う独自の値を入れましょう
# 変数名も独自のものに変えましょう

# ここにPythonプログラムを記述してください

# %%
# 2. dictの要素を更新してみましょう
# 入れる値は何でも良いですが、このNotebookのサンプルプログラムとは違う独自の値を入れましょう
# 変数名も独自のものに変えましょう

# ここにPythonプログラムを記述してください

# %%
#@title 問2 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=2, button_name="練習プログラム"))

# %% [markdown]
# ## 🗑️ サンプルプログラム3　dictの要素の削除

# %% [markdown]
# ### 要素の削除
# - delで要素を削除できます
# - clear()は全要素を削除します

# %%
# delで要素を削除
print("before deletion:", prefecture_type)
del prefecture_type[4]
print("after deletion:", prefecture_type)
# Out:
# before deletion: {1: '北海道', 2: '青森県', 3: '岩手県', 47: '沖縄県', 4: '宮城県'}
# after deletion: {1: '北海道', 2: '青森県', 3: '岩手県', 47: '沖縄県'}

# %% [markdown]
# - 1要素が削除されました

# %%
# clear()は全要素を削除します
print("before clear:", prefecture_type)
prefecture_type.clear()
print("after clear:", prefecture_type)
# Out:
# before clear: {}
# after clear: {}

# %% [markdown]
# - 全ての要素が削除されました

# %% [markdown]
# ## ❌ 練習プログラム3 (8点)
# 1️⃣ dictの要素を1つ削除してみましょう。題材は何でも良いです。
# 2️⃣ dictの要素を全て削除してみましょう

# %%
# 1. dictの要素を1つ削除してみましょう
# 削除する値は何でも良いですが、このNotebookのサンプルプログラムとは違う独自の値を入れましょう
# 変数名も独自のものに変えましょう

# ここにPythonプログラムを記述してください

# %%
# 2. dictの要素を全て削除してみましょう

# ここにPythonプログラムを記述してください

# %%
#@title 問3 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=3, button_name="練習プログラム"))

# %% [markdown]
# ## 💾 サンプルプログラム4　dictの複製
# - リスト同様にミュータブルオブジェクトであるdictは、`=` 演算子で代入すると参照が渡されます
# - copy()で複製すると、元のdictの変更が複製先に反映されません

# %%
prefecture_type = {1:"北海道", 2:"青森県", 3:"岩手県", 47:"沖縄県"}
prefecture_type2 = prefecture_type # `=` 演算子で代入する
prefecture_type[4] = '宮城県'

print('prefecture_type=', prefecture_type)
print('prefecture_type2=', prefecture_type2)
# Out:
# prefecture_type= {1: '北海道', 2: '青森県', 3: '岩手県', 47: '沖縄県', 4: '宮城県'}
# prefecture_type2= {1: '北海道', 2: '青森県', 3: '岩手県', 47: '沖縄県', 4: '宮城県'}

# %% [markdown]
# - `=` 演算子で代入すると参照が渡されるため、prefecture_type を修正すると prefecture_type2 も変更されています

# %%
prefecture_type3 = prefecture_type.copy() # copy()で複製する
prefecture_type[5] = '秋田県'

print('prefecture_type=', prefecture_type)
print('prefecture_type2=', prefecture_type2)
print('prefecture_type3=', prefecture_type3)
# Out:
# prefecture_type= {1: '北海道', 2: '青森県', 3: '岩手県', 47: '沖縄県', 4: '宮城県', 5: '秋田県'}
# prefecture_type2= {1: '北海道', 2: '青森県', 3: '岩手県', 47: '沖縄県', 4: '宮城県', 5: '秋田県'}
# prefecture_type3= {1: '北海道', 2: '青森県', 3: '岩手県', 47: '沖縄県', 4: '宮城県'}

# %% [markdown]
# - copy()で複製すると、元のdictの変更が複製先に反映されません
# - 用途に合わせて適切な方を使いましょう

# %% [markdown]
# ## ⿻ 練習プログラム4 (8点)
# 1️⃣ dictを `=` 演算子で参照渡しして、要素を修正してみましょう。題材は何でも良いです。
# 2️⃣ dictを copy() で複製して、要素を修正してみましょう

# %%
# 1. dictを `=` 演算子で参照渡しして、要素を修正してみましょう
# 修正の仕方は何でも良いですが、このNotebookのサンプルプログラムとは違う独自の値を入れましょう
# 変数名も独自のものに変えましょう

# ここにPythonプログラムを記述してください

# %%
# 2. dictを copy() で複製して、要素を修正してみましょう
# 修正の仕方は何でも良いですが、このNotebookのサンプルプログラムとは違う独自の値を入れましょう
# 変数名も独自のものに変えましょう

# ここにPythonプログラムを記述してください

# %%
#@title 問4 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=4, button_name="練習プログラム"))
