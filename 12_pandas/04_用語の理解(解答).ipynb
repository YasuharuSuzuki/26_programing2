# %% [markdown]
# <a href="https://colab.research.google.com/github/YasuharuSuzuki/26_programing2/blob/main/" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 04_用語の理解

# %% [markdown]
# ## 用語の理解を問う問題
# - 以下の問題について、正解となる選択肢を出力してください
# ※4択問題は1回目の回答のみが有効です。何度も提出することは出来ませんので、ご注意ください。

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題7 Pandasの主要なデータ構造 (3点)
# - Pandasの主要なデータ構造で、1次元のラベル付き配列を表すものを次から選べ
#
#     📕 1. DataFrame
#     📗 2. Series
#     📘 3. Array
#     📙 4. List

# %%
# 正解を出力してください
print('2')
# Out:
# 2

# %% [markdown]
# ---
#
# ### ✅ 解説
# - Seriesは、Pandasの1次元のラベル付き配列を表すデータ構造です。
# - インデックス付きの単一の列のデータを扱うのに適しています。
#
# ---

# %%
#@title 送信処理用共通プログラム（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown 解答の送信に必要です。（中身は絶対に修正しないでください）

import os
os.makedirs(".client/python", exist_ok=True)  # 隠しフォルダを作成
# !wget -q https://raw.githubusercontent.com/YasuharuSuzuki/26_programing2/main/91_notebook_client/src/setup.sh -O .client/setup.sh   # 外部コードをダウンロードして隠しフォルダに配置
# !chmod +x ./.client/setup.sh
# !bash ./.client/setup.sh # 実行

# sandbox実行用
# os.symlink("../../src", ".client", target_is_directory=True)
# !bash ./sandbox_setup.sh # 実行

# モジュールの初期化
exec(open('.client/client_setup.py').read())

# ノートブック固有の設定
NOTEBOOK_PATH = "12_pandas/04_用語の理解.ipynb"
set_notebook_config(NOTEBOOK_PATH)

# %%
#@title 問7 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=7, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題8 条件による行の抽出 (3点)
#
# - DataFrameから「age」列が30以上の行を抽出する記法を次から選べ
#
#     📕 1. df[df['age'] >= 30]
#     📗 2. df[df.age >= 30]
#     📘 3. df.loc[df['age'] >= 30]
#     📙 4. 上記すべて正しい

# %%
# 正解を出力してください
print('4')
# Out:
# 4

# %% [markdown]
# ---
#
# ### ✅ 解説
# 1. ブール値インデックスによる抽出（正しい）
# 2. ドット記法を使った条件抽出（正しい）
# 3. locを使った条件抽出（正しい）
# 4. 正解
#
# ---

# %%
#@title 問8 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=8, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題9 iloc と loc の違い (3点)
#
# - 以下の説明で正しいものを1つ選べ
#
#     📕 1. ilocは列名で指定、locは位置番号で指定する
#     📗 2. locは列名で指定、ilocは位置番号で指定する
#     📘 3. ilocとlocは同じ機能を持つ
#     📙 4. ilocは行のみ、locは列のみを指定できる

# %%
# 正解を出力してください
print('2')
# Out:
# 2

# %% [markdown]
# ---
#
# ### ✅ 解説
# - ilocは列名で指定、locは位置番号で指定する - 逆の説明
# - locは列名で指定、ilocは位置番号で指定する - 正しい説明
# - ilocとlocは同じ機能を持つ - 異なる指定方法を持つ
# - ilocは行のみ、locは列のみを指定できる - 両方とも行と列を指定可能
#
# ---

# %%
#@title 問9 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=9, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題10 DataFrameの基本情報表示 (3点)
#
# - DataFrameの各列のデータ型、非欠損値の個数、メモリ使用量などの基本情報を表示するメソッドを次から選べ
#
#     📕 1. df.summary()
#     📗 2. df.info()
#     📘 3. df.details()
#     📙 4. df.overview()

# %%
# 正解を出力してください
print('2')
# Out:
# 2

# %% [markdown]
# ---
#
# ### ✅ 解説
# 1. df.summary() - 存在しないメソッド
# 2. df.info() - DataFrameの基本情報を表示する正しいメソッド
# 3. df.details() - 存在しないメソッド
# 4. df.overview() - 存在しないメソッド
#
# ---

# %%
#@title 問10 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=10, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題11 箱ひげ図の作成 (3点)
#
# - pandasで箱ひげ図を作成する際に使用する正しいメソッドはどれですか？
#
#     📕 1. df.box()
#     📗 2. df.boxplot()
#     📘 3. df.plot.box()
#     📙 4. df.plot.boxplot()

# %%
# 正解を出力してください
print('3')
# Out:
# 3

# %% [markdown]
# ---
#
# ### ✅ 解説
# 1. df.box() - 存在しないメソッド
# 2. df.boxplot() - DataFrameに直接的なboxplotメソッドは存在しない
# 3. df.plot.box() - 箱ひげ図を作成する正しいメソッド
# 4. df.plot.boxplot() - 存在しないメソッド
#
# ---

# %%
#@title 問11 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=11, button_name="四択問題"))
