# %% [markdown]
# <a href="https://colab.research.google.com/github/YasuharuSuzuki/26_programing2/blob/main/" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 05_用語の理解

# %% [markdown]
# ## 用語の理解を問う問題
# - 以下の問題について、正解となる選択肢を出力してください
# ※4択問題は1回目の回答のみが有効です。何度も提出することは出来ませんので、ご注意ください。

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題13 回帰問題 (3点)
# - 次のうち、回帰問題の例として最も適切なものを選べ
#
#     📕 1. Eメールがスパムかどうかを判定する
#     📗 2. 顧客の年齢を予測する
#     📘 3. 画像が犬か猫かを識別する
#     📙 4. 文章の感情（ポジティブ/ネガティブ）を分析する

# %%
# 正解を出力してください
print('2')
# Out:
# 2

# %% [markdown]
# ---
# ### ✅ 解説
#
# **回帰問題** とは、 **連続した数値（実数値）を予測する問題** のことです。
# たとえば「売上金額」「気温」「身長」「年齢」など、数値そのものを出力する場合が該当します。
#
# #### **各選択肢の解説**
# 📕 1. Eメールがスパムかどうかを判定する
# - 出力は「スパム／スパムでない」という **2つのカテゴリ** であり、 **分類問題** です。
#
# 📗 2. 顧客の年齢を予測する
# - 年齢は **連続的な数値** で表されるため、 **回帰問題** の代表的な例です。
#
# 📘 3. 画像が犬か猫かを識別する
# - 「犬」「猫」という **カテゴリの判別** を行うため、 **分類問題** です。
#
# 📙 4. 文章の感情（ポジティブ/ネガティブ）を分析する
# - 感情を **離散的なラベル** で判定するため、 **分類問題** に該当します。
#
# ---

# %%
#@title 送信処理用共通プログラム（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown 解答の送信に必要です。（中身は絶対に修正しないでください）

import os
os.makedirs(".client/python", exist_ok=True)  # 隠しフォルダを作成
# !wget -q https://raw.githubusercontent.com/YasuharuSuzuki/26_programing2/main/91_notebook_client/src/setup.sh -O .client/setup.sh   # 外部コードをダウンロードして隠しフォルダに配置
# !chmod +x ./.client/setup.sh
# !bash ./.client/setup.sh # 実行

# sandbox実行用
# os.symlink("../../src", ".client", target_is_directory=True)
# !bash ./sandbox_setup.sh # 実行

# モジュールの初期化
exec(open('.client/client_setup.py').read())

# ノートブック固有の設定
NOTEBOOK_PATH = "14_機械学習(回帰)/05_用語の理解.ipynb"
set_notebook_config(NOTEBOOK_PATH)

# %%
#@title 問13 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=13, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題14 過学習 (3点)
#
# - 過学習（Overfitting）の説明として最も適切なものを次から選べ
#
#     📕 1. モデルが訓練データに対して過度に単純である状態
#     📗 2. モデルが訓練データを完全に学習しすぎて、テストデータに対して性能が低下する状態
#     📘 3. モデルが訓練データに対して十分に学習できない状態
#     📙 4. モデルがテストデータに対して過度に複雑である状態

# %%
# 正解を出力してください
print('2')
# Out:
# 2

# %% [markdown]
# ---
#
# ### ✅ 解説
#
# **過学習（Overfitting）** とは、モデルが訓練データの特徴やノイズまで **過剰に学習** してしまい、未知のデータ（テストデータ）に対して **うまく予測できなくなる状態** を指します。
#
# #### **各選択肢の解説**
# 📕 1. モデルが訓練データに対して過度に単純である状態
# - 学習能力が不足している状態であり、 **過少学習（Underfitting）** の説明です。
#
# 📗 2. モデルが訓練データを完全に学習しすぎて、テストデータに対して性能が低下する状態
# - 過学習の典型的な説明であり、正解です。
#
# 📘 3. モデルが訓練データに対して十分に学習できない状態
# - これも **過少学習（Underfitting）** を表しています。
#
# 📙 4. モデルがテストデータに対して過度に複雑である状態
# - モデルの複雑さは訓練時に決まるものであり、表現として不適切です。
# 過学習は「訓練データへの適合しすぎ」が本質です。
#
# ---

# %%
#@title 問14 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=14, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題15 目的変数 (3点)
#
# - 次のうち目的変数（Target Variable）の説明として最も適切なものを次から選べ
#
#     📕 1. モデルを学習する際に入力データとなる、ある現象や値の原因となる変数のこと
#     📗 2. モデルを学習させることで予測したい変数のこと
#     📘 3. アンケート調査データの場合の無回答項目やカルテデータの場合の未検査項目のように，あるケースのある項目の値が欠落している変数のこと
#     📙 4. モデルの性能を評価する指標のこと

# %%
# 正解を出力してください
print('2')
# Out:
# 2

# %% [markdown]
# ---
#
# ### ✅ 解説
#
# **目的変数（Target Variable）** とは、機械学習モデルにおいて最終的に **予測・推定したい対象となる変数** のことです。
# 回帰問題では数値、分類問題ではクラス（ラベル）が目的変数になります。
#
# #### **各選択肢の解説**
# 📕 1. モデルを学習する際に入力データとなる、ある現象や値の原因となる変数のこと
# - これは **説明変数（特徴量、入力変数）** の説明であり、目的変数ではありません。
#
# 📗 2. モデルを学習させることで予測したい変数のこと
# - 目的変数の定義として最も適切であり、 **正解** です。
#
# 📘 3. アンケート調査データの場合の無回答項目やカルテデータの場合の未検査項目のように，あるケースのある項目の値が欠落している変数のこと
# - これは **欠損値（Missing Value）** に関する説明です。
#
# 📙 4. モデルの性能を評価する指標のこと
# - これは **評価指標（Accuracy、RMSE など）** の説明であり、目的変数ではありません。
#
# ---

# %%
#@title 問15 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=15, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題16 ルールベース (3点)
#
# - ルールベースから機械学習へと移行が進んだ理由として適切でないものを次の中から1つ選べ。
#
#     📕 1. 複雑な状況に対応するには、ルールの数が膨大になり、人手による管理が困難だったため
#     📗 2. 現実の問題では曖昧さや例外が多く、機械学習の方が柔軟に対応できるため
#     📘 3. ルールベースは専門家の知識を忠実に再現でき、さらに構築後に新たな知識を自動で取り込むなど、継続的な改善が容易だったため
#     📙 4. ビッグデータの活用と計算資源の向上により、機械学習の予測精度が実用レベルに達したため

# %%
# 正解を出力してください
print('3')
# Out:
# 3

# %% [markdown]
# ---
#
# ### ✅ 解説
#
# 本問は「ルールベースから機械学習へ移行した理由として **適切でない** もの」を選ぶ問題です。
#
# #### **各選択肢の解説**
#
# 📕 1. 複雑な状況に対応するには、ルールの数が膨大になり、人手による管理が困難だったため
# - ルールベースの代表的な課題であり、**機械学習へ移行した正当な理由** です。
#
# 📗 2. 現実の問題では曖昧さや例外が多く、機械学習の方が柔軟に対応できるため
# - ルールで明確に定義しにくい問題に対し、 **データから学習できる** 点は、機械学習が選ばれる大きな理由です。
#
# 📘 3. ルールベースは専門家の知識を忠実に再現でき、さらに構築後に新たな知識を自動で取り込むなど、継続的な改善が容易だったため
# - ルールベースは人手でルールを追加・修正する必要があり、自動的に知識を取り込んで改善することは困難です。
# そのため、この内容は移行理由として不適切であり、**正解** です。
#
# 📙 4. ビッグデータの活用と計算資源の向上により、機械学習の予測精度が実用レベルに達したため
# - 技術基盤の進歩により、機械学習が実用化されたことは、**ルールベースから移行が進んだ重要な背景** です。
#
# ---

# %%
#@title 問16 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=16, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## 問17 性能を評価するために使用するデータ (3点)
#
# - 学習済みモデルの性能を評価する際に使用するのはどのデータか？
#
#     📕 1. テストデータ
#     📗 2. 訓練データ
#     📘 3. 説明変数
#     📙 4. 水増しデータ

# %%
# 正解を出力してください
print('1')
# Out:
# 1

# %% [markdown]
# ---
#
# ### ✅ 解説
#
# 学習済みモデルの性能評価では、モデルが **まだ見たことのないデータに対して** どれだけ正しく予測できるかを確認する必要があります。
# そのため、学習には使用していないテストデータを用いて評価を行います。
#
# #### **各選択肢の解説**
#
# 📕 1. テストデータ
# - 学習に使われていないデータであり、 **汎化性能（未知データへの対応力）** を評価するために使用します。
# よって **正解** です。
#
# 📗 2. 訓練データ
# - モデルを学習させるためのデータであり、これで評価すると **過学習に気づけない** ため、性能評価には不適切です。
#
# 📘 3. 説明変数
# - 入力データの項目を指す用語であり、データの種類（訓練・テスト）を表すものではありません。
#
# 📙 4. 水増しデータ
# - データ拡張（Data Augmentation）によって生成されたデータであり、学習用に使われることはありますが、**性能評価用のデータではありません** 。
#
# ---

# %%
#@title 問17 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=17, button_name="四択問題"))
